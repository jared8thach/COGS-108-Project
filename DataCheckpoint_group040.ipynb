# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# # Names
#
# - Shawn Oh
# - Jesse Liang
# - Jared Thach
# - Kenzie Nguyen

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# What conditions are most important, specifically correlated, with economic productivity?

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# 1) **Fraser Institute - Economic Freedom (Approach):**
# - Dataset Name: Economic Freedom Rankings
#     - **Note: There are gonna be A LOT of these (47 aside from the one I played with to be exact if I'm counting right)**
# - Link: https://www.fraserinstitute.org/economic-freedom/dataset?geozone=world&year=2018&page=dataset&min-year=2&max-year=0&filter=0
# - Number of observations: 164
#
# - Description: This dataset provides ranking for a number of quantifiable aspects relevant to countries' economies
#
# 2) **Long Term Productivity Database (Data)**
# - Dataset names
#     - lpd_GDPpc - Observations: 130
#     - lpd_LP - Observations: 130
#     - lpd_TFP - Observations: 130
#     - lpd_KI - Observations: 130
#     - lpd_AgeK - Observations: 130
# - Link: http://longtermproductivity.com/download.html
#
# - Description: This dataset provides summary statistics about various countries' economic outputs
#
# ****
#
# **If you plan to use multiple datasets, add 1-2 sentences about how you plan to combine these datasets.**
#
# Response to the above:
# - The Economic Freedom Rankings datasets can be combined with themselves in multiple ways, such as...
#     - 1. All together to get an average
#     - 2. Combined on significant time periods
#     - 3. Used together to show how values change(d) from year to year
#
# - The Longterm Productivity dataset could be combined with the Economic Freedom Rankings to get everything in one
#     - **Note:** There are very few countries present in this dataset relative to the Economic Freedom Rankings

# %% [markdown]
# # Setup

# %%
# Importing pandas & numpy
import pandas as pd

# https://stackoverflow.com/questions/49188960/how-to-show-all-of-columns-name-on-pandas-dataframe
# ^^ What I read to get all of the column names to show
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Reading in Data

# %% [markdown]
# ### Reading in the full version of the Economic Freedom Rankings Dataset

# %%
# https://stackoverflow.com/questions/37400974/unicode-error-unicodeescape-codec-cant-decode-bytes-in-position-2-3-trunca
# ^^ Shift + right clicked to get the file path, wasn't working so I looked up the error and found the link above

# The full version of the 'Economic Freedom Rankings' dataset will be read in as efr for now
efr = pd.ExcelFile(r"C:\Users\kenzi\Desktop\COGS 108\group040_wi21\Economic_Freedom_Rankings.xlsx")
report2020 = pd.read_excel(efr, 'EFW Data 2020 Report')

# %%
# report2020 isn't particularly useful as it's just all of the datasets "stacked together"
# report2020

# %% [markdown]
# ### Reading in the 2018 only version of the Economic Freedom Rankings Dataset
# - Looking at it & getting information before cleaning it as well

# %%
# Instead of using report2020, it might be better to just download the datasets for each year...
# run them through the same "cleaning" process so they can be easily worked with
efr2018 = pd.read_csv(r"C:\Users\kenzi\Desktop\COGS 108\group040_wi21\Economic_Freedom_Rankings_2018.csv")
# efr2018

# %%
# efr2018.shape
# 166 rows x 73 columns

# efr2018.dtypes
# All column names are/should? objects, but more specifically strings

efr2018.columns
# The column names don't show up? 0. o
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Area 1', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Area 2', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Area 3', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Area 4', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Area 5',
#        'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57',
# ...

# %% [markdown]
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
#        'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
#        'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53',
#        'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57',
#        'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61',
#        'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65',
#        'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69',
#        'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72'],
#       dtype='object')

# %% [markdown]
# ### Reading in the Longterm Productivity Database
# - Looking at it & getting information before cleaning it as well

# %%
# The Longterm Productivity Database dataset will be read in as lpd for now
lpd_readIn = pd.ExcelFile(r"C:\Users\kenzi\Desktop\COGS 108\group040_wi21\Longterm_Productivity_Database.xlsx")

# Reading in the individual pages
lpd_GDPpc = pd.read_excel(lpd_readIn, 'GDP per capita')
lpd_LP = pd.read_excel(lpd_readIn, 'Labor Productivity')
lpd_TFP = pd.read_excel(lpd_readIn, 'TFP')
lpd_KI = pd.read_excel(lpd_readIn, 'KI')
lpd_AgeK = pd.read_excel(lpd_readIn, 'AgeK')

# Meanings
# GPDpc - Gross Domestic Product per capita
# LP - Labor productivity
# TFP - Total Factor Productivity
# KI - Capital Intensity
# Age - Average age of equipmen capital stock

# NOTE: LP, TFP< KI & GPDpc are based of $US 2010 purchasing power parity (ppp)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **2018 Economic Freedom Dataset**
# - Had to drop some rows and columns
# - Renamed all the columns using a dictionary
# - Replaced null values with 0 afterwards
#
# **Longterm Productivity Dataset**
# - The data is already tidy for these, so we just replaced null values with 0

# %% [markdown]
# ### Cleaning the 2018 Economic Freedom dataset

# %%
# Renaming the columns
efr2018 = efr2018.rename(columns = {"Unnamed: 0": "Year"})
efr2018
# Out:
#      Year Unnamed: 1    Unnamed: 2                      Unnamed: 3 Unnamed: 4  \
# 0     NaN        NaN           NaN                             NaN        NaN
# 1     NaN        NaN           NaN                             NaN        NaN
# 2    Year   ISO_Code     Countries  Economic Freedom Summary Index       Rank
# 3    2018        AGO        Angola                            4.75        159
# 4    2018        ALB       Albania                             7.8         26
# ..    ...        ...           ...                             ...        ...
# 160  2018        VNM       Vietnam                             6.2        125
# 161  2018        YEM   Yemen, Rep.                            5.51        149
# 162  2018        ZAF  South Africa                            6.73         90
# 163  2018        ZMB        Zambia                            7.19         69
# 164  2018        ZWE      Zimbabwe                            5.12        155
#
# ...

# %%
# Creating a dictionary to rename the rest of the columns
# Might want to change the names later on to make them easier to type?

# Can use this dictionary to rename what will be all of the other datasets' column names later
efr2018_columnsDict = {
'Unnamed: 1' : 'ISO_Code',
'Unnamed: 2' : 'Countries',
'Unnamed: 3' : 'Economic_Freedom_Summary_Index',
'Unnamed: 4' : 'Rank',
'Unnamed: 5' : 'Quartile',
'Area 1' : '1A_Government Consumption',
'Unnamed: 7' : '1A_Data',
'Unnamed: 8' : '1B_Transfers_and_Subsidies',
'Unnamed: 9' : '1B_Data',
'Unnamed: 10' : '1C_Government_Investment',
'Unnamed: 11' : '1C_Data',
'Unnamed: 12' : '1Di_Top_Marginal_Income_Tax_Rate',
'Unnamed: 13' : '1Di_Data',
'Unnamed: 14' : '1Dii_Top_Marginal_Income_And_Payroll_Tax_Rate',
'Unnamed: 15' : '1Dii_Data',
'Unnamed: 16' : 'Top_Marginal_Tax_Rate',
'Unnamed: 17' : 'State_Ownership_Of_Assets',
'Unnamed: 18' : 'Size_of_Government',
'Area 2' : '2A_Judicial Independence',
'Unnamed: 20' : '2B_Impartial_Rights',
'Unnamed: 21' : '2C_Protection_Of_Property_Rights',
'Unnamed: 22' : '2D_Military_Interference_In_Rule_Of_Law_And_Politics',
'Unnamed: 23' : '2E_Integrity_Of_The_Legal_System',
'Unnamed: 24' : '2F_Legal_Enforcement_Of_Contracts',
'Unnamed: 25' : '2G_Regulatory_Restrictions_On_The_Sale_Of_Real_Property',
'Unnamed: 26' : '2H_Reliability_Of_Police',
'Unnamed: 27' : 'Gender_Legal_Rights_Adjustment',
'Unnamed: 28' : 'Legal_System_&_Property_Rights',
'Area 3' : '3A_Money_Growth',
'Unnamed: 30' : '3A_Data',
'Unnamed: 31' : '3B_Standard_Deviation_Of_Inflation',
'Unnamed: 32' : '3B_Data',
'Unnamed: 33' : '3C_Inflation:_Most_Recent_Year',
'Unnamed: 34' : '3C_Data',
'Unnamed: 35' : '3D_Freedom_To_Own_Foreign_Currency_Bank_Accounts',
'Unnamed: 36' : 'Sound Money',
'Area 4' : '4Ai_Revenue_From_Trade_Taxes_(%_Of_Trade_Sector)',
'Unnamed: 38' : '4Ai_Data',
'Unnamed: 39' : '4Aii_Mean_Tariff_Rate',
'Unnamed: 40' : '4Aii_Data',
'Unnamed: 41' : '4Aiii_Standard_Deviation_Of_Tariff_Rates',
'Unnamed: 42' : '4Aiii_Data',
'Unnamed: 43' : 'Tariffs',
'Unnamed: 44' : '4Bi_Non_Tariff_Trade_Barriers',
'Unnamed: 45' : '4Bii_Compliance_Costs_Of_Importing_And_Exporting',
'Unnamed: 46' : 'Regulatory Trade Barriers',
'Unnamed: 47' : '4C_Black_Market_Exchange_Rates',
'Unnamed: 48' : '4Di_Financial_Openness',
'Unnamed: 49' : '4Dii_Capital_Controls',
'Unnamed: 50' : '4Diii_Freedom_Of_Foreigners_To_Visit',
'Unnamed: 51' : 'Controls_Of_The_Movement_Of_Capital_And_People',
'Unnamed: 52' : 'Freedom_To_Trade_Internationally',
'Area 5' : '5Ai_Ownership_Of_Banks',
'Unnamed: 54' : '5Aii_Private_Sector_Credit',
'Unnamed: 55' : '5Aiii_Interest_Rate_Controls/Negative_Real_Interest_Rates',
'Unnamed: 56' : 'Credit_Market_Regulations',
'Unnamed: 57' : '5Bi_Hiring_Regulations_And_Minimum_Wage',
'Unnamed: 58' : '5Bii_Hiring_And_Firing_Regulations',
'Unnamed: 59' : '5Biii_Centralized_Collective_Bargaining',
'Unnamed: 60' : '5Biv_Hours_Regulations',
'Unnamed: 61' : '5Bv_Mandated_Cost_Of_Worker_Dismissal',
'Unnamed: 62' : '5Bvi_Conscription',
'Unnamed: 63' : 'Labor_Market_Regulations',
'Unnamed: 64' : '5Ci_Administrative_Requirements',
'Unnamed: 65' : '5Cii_Regulatory_Burden',
'Unnamed: 66' : '5Ciii_Starting_A_Business',
'Unnamed: 67' : '5Civ_Impartial_Public_Administration',
'Unnamed: 68' : '5Cv_Licensing_Restrictions',
'Unnamed: 69' : '5Cvi_Tax_Compliance',
'Unnamed: 70' : 'Business_Regulations',
'Unnamed: 71' : 'Regulation',
}

# %%
efr2018 = efr2018.rename(columns = efr2018_columnsDict)
efr2018
# Out:
#      Year  ISO_Code     Countries  Economic_Freedom_Summary_Index  Rank  \
# 0     NaN       NaN           NaN                             NaN   NaN
# 1     NaN       NaN           NaN                             NaN   NaN
# 2    Year  ISO_Code     Countries  Economic Freedom Summary Index  Rank
# 3    2018       AGO        Angola                            4.75   159
# 4    2018       ALB       Albania                             7.8    26
# ..    ...       ...           ...                             ...   ...
# 160  2018       VNM       Vietnam                             6.2   125
# 161  2018       YEM   Yemen, Rep.                            5.51   149
# 162  2018       ZAF  South Africa                            6.73    90
# 163  2018       ZMB        Zambia                            7.19    69
# 164  2018       ZWE      Zimbabwe                            5.12   155
#
#      Quartile 1A_Government Consumption  1A_Data 1B_Transfers_and_Subsidies  \
# ...

# %%
# Dropping the first 2 rows because they only contained information that's now in the column names themselves
efr2018 = efr2018.drop([0, 1, 2])
efr2018
# Out:
#      Year ISO_Code             Countries Economic_Freedom_Summary_Index Rank  \
# 3    2018      AGO                Angola                           4.75  159
# 4    2018      ALB               Albania                            7.8   26
# 5    2018      ARE  United Arab Emirates                           7.05   74
# 6    2018      ARG             Argentina                           5.78  144
# 7    2018      ARM               Armenia                           7.92   18
# ..    ...      ...                   ...                            ...  ...
# 160  2018      VNM               Vietnam                            6.2  125
# 161  2018      YEM           Yemen, Rep.                           5.51  149
# 162  2018      ZAF          South Africa                           6.73   90
# 163  2018      ZMB                Zambia                           7.19   69
# 164  2018      ZWE              Zimbabwe                           5.12  155
#
# ...

# %%
# Resetting the indices since the first 3 rows were dropped
efr2018 = efr2018.reset_index()
# efr2018

# %%
# There are null values in this dataframe, so we'll just...
# replace them all with 0s, which should be okay for now

efr2018.isnull().values.any()
efr2018.fillna(0)
# Out:
#      index  Year ISO_Code             Countries  \
# 0        3  2018      AGO                Angola
# 1        4  2018      ALB               Albania
# 2        5  2018      ARE  United Arab Emirates
# 3        6  2018      ARG             Argentina
# 4        7  2018      ARM               Armenia
# ..     ...   ...      ...                   ...
# 157    160  2018      VNM               Vietnam
# 158    161  2018      YEM           Yemen, Rep.
# 159    162  2018      ZAF          South Africa
# 160    163  2018      ZMB                Zambia
# 161    164  2018      ZWE              Zimbabwe
#
#     Economic_Freedom_Summary_Index Rank Quartile 1A_Government Consumption  \
# 0                             4.75  159        4                       7.7
# 1                              7.8   26        1                      8.16
# 2                             7.05   74        2                      4.29
# 3                             5.78  144        4                      5.94
# ...

# %% [markdown]
# ### Cleaning the Longterm Productivity dataset

# %%
# There are null values in all of these dataframes, so we'll just...
# replace them all with 0s, which should be okay for now

# lpd_GDPpc.isnull().values.any()
# lpd_LP.isnull().values.any()
# lpd_TFP.isnull().values.any()
# lpd_KI.isnull().values.any()
# lpd_AgeK.isnull().values.any()

lpd_GDPpc = lpd_GDPpc.fillna(0)
lpd_LP = lpd_LP.fillna(0)
lpd_TFP = lpd_TFP.fillna(0)
lpd_KI = lpd_KI.fillna(0)
lpd_AgeK = lpd_AgeK.fillna(0)

# %% [markdown]
# # Project Proposal (updated)

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/3 Wed | 5 PM  | Search for datasets, download and import datasets  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 2/6 Sat | 5 PM  | Clean and Wrangle Data (Shawn); EDA (Jessie) | Review cleaned dataset, check for null values and anomalous data   |
# | 2/10 Wed | 5 PM  | Finish Wrangling Data, EDA (Kenzie); Begin Analysis (Jared) | Discuss/edit Analysis; Complete project check-in |
# | 2/13 Sat | 5 PM  | Complete analysis; Draft results/conclusion/discussion (Wasp)| Edit and proof-read finished project |
# | 2/17 Wed | 5 PM  | NA | Turn in Final Project & Group Project Surveys |
# | 3/19 Fri | 5 PM  | NA | Turn in Final Project & Group Project Surveys |
